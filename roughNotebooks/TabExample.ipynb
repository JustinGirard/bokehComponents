# %%
import sys
sys.path.append('../../')

from bokehComponents.Dashboard import Dashboard

from bokeh.io import output_notebook,output_file
from bokeh.application.handlers import FunctionHandler
from bokeh.application import Application
from bokeh.models.widgets import Panel, Tabs #, DataTable, DateFormatter, TableColumn, Tabs, 
from bokeh.layouts import layout
from bokeh.plotting import figure,show,output_file
from bokeh.models import Div

# %% [markdown]
# # bokehComponents
# bokehComponents is an open source library that allows python developers to create interactive web applications with Bokeh more easily. These components were  born out of frustration felt when fighting with analytics libraries, and out of a need to share analytics functions across teams, businesses, academic projects and hbby projects.I am happy to share these time saving object oriented libraries with the world, and hope to keep refactoring them over the years.

# %% [markdown]
# # 1. tabs
# In this notebook we will outline how to use one of the most basic Bokeh Components, the tab. Other notebooks show more exciting features, and are each designed to be independent.
#
# ### Status: In Development
# Note, the library is in active development, and virtually all method names or class names, or parameters may change. Having said that, I have developed a suite of unit tests which we commit to passing, at least internally.

# %% [markdown]
# ### 1.1 The Dashboard
# Every Bokeh component has be be embedded into an application. To do this we extend from the basic dashboard application, and add in our button. By default, the dashboard is designed to render within a jupyer notebook.

# %%
class BlankDashboard(Dashboard):
    def getLayout(self):
        l = layout([Div(text="Example <b>HTML</b>", width=200, height=100)],sizing_mode='fixed')         
        return l
d = BlankDashboard()
d.showDashboard()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="6e58438a-d909-4ea6-8028-ccc9bdf120ff">Loading BokehJS ...</span>
#     </div>
# <script src="http://ec2.paxculturastudios.com:33085/autoload.js?bokeh-autoload-element=97958593-a310-400f-b671-7772197693a1&bokeh-absolute-url=http://ec2.paxculturastudios.com:33085&resources=none" id="97958593-a310-400f-b671-7772197693a1"></script>

# %% [markdown]
# ### 1.2 Two Tabs
# The most basic analytics applications you will create will likely be broken into tabs. In the folliwng example we illustrate how to create a couple of tabs.

# %%
class TwoTabDashboard(Dashboard):
    def getLayout(self):
        panel1 = Panel(child=layout([ Div(text="TAB1 <b>HTML</b>", width=200, height=100)], sizing_mode='fixed'),title="Tab 1")
        panel2 = Panel(child=layout([ Div(text="TAB2 <script>console.log(1);</script><a href='https://www.google.com'>google</a>", width=200, height=100)], sizing_mode='fixed'),title="Tab 2")
        
        # Include panels as tabs
        tabs = Tabs(tabs=[ panel1,panel2], width=700)        
        l = layout([tabs],sizing_mode='fixed')         
        return l
d = TwoTabDashboard()
d.showDashboard()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="8fd7ef87-5438-43db-89cd-df1d94128b01">Loading BokehJS ...</span>
#     </div>
# <script src="http://ec2.paxculturastudios.com:36137/autoload.js?bokeh-autoload-element=5dcdc75c-9448-4ade-9d97-d06a28a393be&bokeh-absolute-url=http://ec2.paxculturastudios.com:36137&resources=none" id="5dcdc75c-9448-4ade-9d97-d06a28a393be"></script>
